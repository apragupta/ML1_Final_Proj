# %% [markdown]
# # Initial model to classify images into sentiments based on the sentiment of their caption

# %%
import pandas as pd

# %%
##Load 10k sample with sentiment labels from hugging face
data_df = pd.read_csv('data/initial_sample/sent_added')

# %%
data_df
# Out:
#       index                                            caption  \
# 0         0                        snowman on a red background
# 1         1  celebrity celebrates with his team mates after...
# 2         2  action shot of basketball player , passing the...
# 3         3                       a sunny winter day by lake .
# 4         4  the extraordinary domed ceiling , with an arti...
# ...     ...                                                ...
# 9298   9625                     adapted work to the universe .
# 9299   9626         praying and folding hands over poetry book
# 9300   9627  cute hand drawn seamless pattern with circles ...
# 9301   9628             view of a rocky coast in the evening .
# 9302   9629  nebula and his clouds of interstellar dust and...
#
#                                                    link  \
# 0     https://thumb10.shutterstock.com/display_pic_w...
# 1     https://media.gettyimages.com/photos/david-bec...
# ...
